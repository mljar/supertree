# %%
from supertree import SuperTree
from sklearn import datasets
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import GradientBoostingClassifier

# %%
rows, cols = 100, 5

X_class, y_class = datasets.make_classification(
    n_samples=rows, n_features=cols, n_informative=cols, n_redundant=0, n_repeated=0, n_classes=5, random_state=124)


feature_names_class = [f"f_{i}" for i in range(cols)]
target_names_class = [f"class_{i}" for i in range(len(set(y_class)))]

X_reg, y_reg = datasets.make_regression(
    n_samples=rows, n_features=cols, noise=0.1, random_state=123)


feature_names_reg = [f"f_{i}" for i in range(cols)]
target_names_reg = ["regression_target"]

# %%
gb_classifier = GradientBoostingClassifier(n_estimators=100, random_state=42)

gb_classifier.fit(X_class, y_class)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
st = SuperTree(gb_classifier,X_class,y_class,feature_names_class, target_names_class)

# %%
st.save_json_tree("output",3)
# Out:
# JSON data saved to output.json

# %%
st.show_tree(3)
# Out:
#     <script src="https://cdn.jsdelivr.net/npm/d3@7" charset="utf-8"></script>
#     <script src="https://cdn.jsdelivr.net/npm/tweetnacl@1.0.3/nacl.min.js"></script>
#     <script src="https://cdn.jsdelivr.net/npm/tweetnacl-util@0.15.1/nacl-util.min.js"></script>
#     <style >
# .st-dropdown {
#   border: 1px solid #007B9A;
#   background-color: #008CBA;
#   color: #ffffff;
#   border: 2px solid #007B9A;
#   text-align: center;
#   text-decoration: none;
#   font-size: 16px;
#   margin-top: -30px;
#   margin: 0px;
#   width: 150px;
#   padding: 10px;
# }
#
# .st-option-button {
#   border: 1px solid #007B9A;
#   border-radius: 0px;
#   background-color: #008CBA;
#   border: 2px solid #007B9A;
#   color: white;
#   padding: 7px 28px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 16px;
#   cursor: pointer;
#   transition: background-color 0.3s, box-shadow 0.3s;
# }
#
# .st-option-button:hover {
#     background-color: #45a049;
#     box-shadow: 0 5px 15px rgba(0, 0, 0, 0.3);
# }
#
# .st-body-toolbar-div {
#   margin: 0;
#   padding: 0;
#   /* flex-grow: 1; */
#   max-height: 100;
# }
#
#
#
#
# .st-logo-button svg {
#   width: 100%;
#   height: 100%;
# }
#
#
#
#
#
#
#
# .st-svg {
#   width: 100%;
#   height: 1000px;
# }
#
#
#
# .st-target {
#   font-family: lato;
#   font-size: 10px;
#   fill: #333333;
# }
#
#
# .st-pie-target {
#   font-family: lato;
#   font-size: 10px;
#   fill: #333333;
# }
#
#
# .st-pie-target2 {
#   font-family: lato;
#   font-size: 10px;
#   fill: #333333;
# }
#
# .st-grid path {
#   stroke-width: 0;
#   stroke: #333333;
# }
#
# .st-grid .tick line {
#   stroke: #333333;
#   stroke-width: 0.3px;
#   stroke-opacity: 0.3;
# }
#
#
# .st-tooltip {
#   background-color: #ffffff;
#   font-family: lato;
#   font-size: 11px;
#   padding: 4px;
#   color: #666666;
#   border: none;
#   box-shadow: 0px 0px 3px 0px #E6E6E6;
# }
#
# .st-modal {
#     display: none;
#     position: fixed;
#     z-index: 1000;
#     left: 0;
#     top: 0;
#     width: 100%;
#     height: 100%;
#     overflow: auto;
#     background-color: rgba(0, 0, 0, 0.7);
# }
#
#
# .st-modal-content {
#     background-color: #fefefe;
#     margin: auto;
#     padding: 20px;
#     border: 1px solid #888;
#     width: 90%;
#     height: 90%;
#     max-width: 90%;
#     max-height: 90%;
#     text-align: center;
#     overflow: auto;
#     position: absolute;
#     top: 50%;
#     left: 50%;
#     transform: translate(-50%, -50%);
#     display: flex;
#     flex-direction: column;
# }
#
#
#
# .st-container {
#     background-color: #fefefe;
#     width: 100%;
#     height: 100vh;
#     text-align: center;
#     display: flex;
#     overflow: hidden;
#     flex-direction: column;
#     gap: 0;
#     padding: 0;
#     margin: 0;
# }
#
#
# .st-body-tree-div {
#   min-height: 1000px;
# }
#
#
# .st-logo {
#   cursor: pointer;
#   display: inline-block;
#   margin: 0;
#   padding: 0;
#   position: absolute;
# }
#
#
#
#
# .st-container > div {
#     margin: 0;
#     padding: 0;
# }
#
#
#
# .st-closeBtn {
#     color: #aaa;
#     position: absolute;
#     float: right;
#     font-size: 28px;
#     font-weight: bold;
#     top: 10px;
#     right: 20px;
# }
#
# .st-closeBtn:hover,
# .st-closeBtn:focus {
#     color: black;
#     text-decoration: none;
#     cursor: pointer;
# }
#
#
#
# .st-logo-button {
#
#   height: 100%;
#   padding: 14px 28px;
#   background: #008CBA;
#   border: none;
#   padding: 0;
#   margin: 0;
#   cursor: pointer;
#   justify-content: center;
#   align-items: center;
#
#
# }
#
#
# .bold-link {
#     background-color: #008CBA;
#     color: white;
# }
#
# .bold-link:hover {
#     background-color: #007bb5;
# }
#
#
# .st-openModal {
#     background-color: #008CBA;
#     border: 2px solid #007B9A;
#     color: white;
#     padding: 14px 28px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     margin: 4px 2px;
#     cursor: pointer;
#     border-radius: 8px;
#     transition: background-color 0.3s, box-shadow 0.3s;
# }
#
# .st-openModal:hover {
#     background-color: #45a049;
#     box-shadow: 0 5px 15px rgba(0, 0, 0, 0.3);
# }
#
# .st-tree-div {
#     flex-grow: 1;
#     display: flex;
#     justify-content: center;
#     align-items: center;
# }
#
# .jp-RenderedHTMLCommon img, .jp-RenderedImage img, .jp-RenderedHTMLCommon svg, .jp-RenderedSVG svg {
#     max-width: none;
#     height: 100%;
# }
#
#
#  </style>
#     <html>
#
#     <div id="my-window" class="st-container">
#         <div id="toolbar-63309" class="st-body-toolbar-div"></div>
#         <div id="graph-div-63309" class="st-body-tree-div-63309"></div>
#     </div>
#     </html>
#     <script > function buildTree(
#   Key = "key",
#   pathJson = "data/treedata.json",
#   pytree = {"node_data": {"feature": 3, "threshold": -0.619, "impurity": 0.107, "samples": 100, "class_distribution": [[19, 19, 21, 21, 20]], "treeclass": "No data", "is_leaf": false, "start_end_x_axis": [["notexist", "notexist"], ["notexist", "notexist"], ["notexist", "notexist"], ["notexist", "notexist"], ["notexist", "notexist"]], "left_node": {"feature": 1, "threshold": 0.756, "impurity": 0.174, "samples": 33, "class_distribution": [[13, 5, 7, 1, 7]], "treeclass": "No data", "is_leaf": false, "start_end_x_axis": [["notexist", "notexist"], ["notexist", "notexist"], ["notexist", "notexist"], [-0.619, "notexist"], ["notexist", "notexist"]], "left_node": {"feature": 4, "threshold": -2.036, "impurity": 0.12, "samples": 21, "class_distribution": [[4, 5, 6, 0, 6]], "treeclass": "No data", "is_leaf": false, "start_end_x_axis": [["notexist", "notexist"], [0.756, "notexist"], ["notexist", "notexist"], [-0.619, "notexist"], ["notexist", "notexist"]], "left_node": {"feature": -2, "threshold": -2.0, "impurity": 0.0, "samples": 2, "class_distribution": [[2, 0, 0, 0, 0]], "treeclass": "No data", "is_leaf": true, "start_end_x_axis": [["notexist", "notexist"], [0.756, "notexist"], ["notexist", "notexist"], [-0.619, "notexist"], [-2.036, "notexist"]], "left_node": null, "right_node": null}, "right_node": {"feature": -2, "threshold": -2.0, "impurity": 0.082, "samples": 19, "class_distribution": [[2, 5, 6, 0, 6]], "treeclass": "No data", "is_leaf": true, "start_end_x_axis": [["notexist", "notexist"], [0.756, "notexist"], ["notexist", "notexist"], [-0.619, "notexist"], ["notexist", -2.036]], "left_node": null, "right_node": null}}, "right_node": {"feature": 4, "threshold": -0.948, "impurity": 0.155, "samples": 12, "class_distribution": [[9, 0, 1, 1, 1]], "treeclass": "No data", "is_leaf": false, "start_end_x_axis": [["notexist", "notexist"], ["notexist", 0.756], ["notexist", "notexist"], [-0.619, "notexist"], ["notexist", "notexist"]], "left_node": {"feature": -2, "threshold": -2.0, "impurity": 0.182, "samples": 3, "class_distribution": [[1, 0, 1, 1, 0]], "treeclass": "No data", "is_leaf": true, "start_end_x_axis": [["notexist", "notexist"], ["notexist", 0.756], ["notexist", "notexist"], [-0.619, "notexist"], [-0.948, "notexist"]], "left_node": null, "right_node": null}, "right_node": {"feature": -2, "threshold": -2.0, "impurity": 0.073, "samples": 9, "class_distribution": [[8, 0, 0, 0, 1]], "treeclass": "No data", "is_leaf": true, "start_end_x_axis": [["notexist", "notexist"], ["notexist", 0.756], ["notexist", "notexist"], [-0.619, "notexist"], ["notexist", -0.948]], "left_node": null, "right_node": null}}}, "right_node": {"feature": 4, "threshold": -0.768, "impurity": 0.057, "samples": 67, "class_distribution": [[6, 14, 14, 20, 13]], "treeclass": "No data", "is_leaf": false, "start_end_x_axis": [["notexist", "notexist"], ["notexist", "notexist"], ["notexist", "notexist"], ["notexist", -0.619], ["notexist", "notexist"]], "left_node": {"feature": 3, "threshold": 0.631, "impurity": 0.133, "samples": 17, "class_distribution": [[5, 7, 4, 1, 0]], "treeclass": "No data", "is_leaf": false, "start_end_x_axis": [["notexist", "notexist"], ["notexist", "notexist"], ["notexist", "notexist"], ["notexist", -0.619], [-0.768, "notexist"]], "left_node": {"feature": -2, "threshold": -2.0, "impurity": 0.146, "samples": 7, "class_distribution": [[5, 1, 1, 0, 0]], "treeclass": "No data", "is_leaf": true, "start_end_x_axis": [["notexist", "notexist"], ["notexist", "notexist"], ["notexist", "notexist"], [0.631, -0.619], [-0.768, "notexist"]], "left_node": null, "right_node": null}, "right_node": {"feature": -2, "threshold": -2.0, "impurity": 0.0, "samples": 10, "class_distribution": [[0, 6, 3, 1, 0]], "treeclass": "No data", "is_leaf": true, "start_end_x_axis": [["notexist", "notexist"], ["notexist", "notexist"], ["notexist", "notexist"], ["notexist", 0.631], [-0.7

# %%
st.save_html("output",3)
# Out:
# HTML saved to output.html
